# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

# %%
left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'CountryID': [3,4],
              'Country': ['Pandama', 'Spain']}

# %%
right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    CountryID  Country
# 0          3  Pandama
# 1          4    Spain

# %%
inner_join = left_table_df.merge(right_table_df,on='CountryID')

# %%
inner_join
# Out:
#          Date  CountryID  Units  Country
# 0  03-01-2020          3     30  Pandama

# %%
right_table = {'ID': [3,4],
              'Country': ['Pandama', 'Spain']}

# %%
right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
inner_join=left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID')
inner_join
# Out:
#          Date  CountryID  Units  ID  Country
# 0  03-01-2020          3     30   3  Pandama

# %%
inner_join=left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID').drop(['ID','Units'],axis=1)
inner_join
# Out:
#          Date  CountryID  Country
# 0  03-01-2020          3  Pandama

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]
             }

# %%
left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
inner_join=left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID',suffixes=['_left','_right']).drop('ID',axis=1)
inner_join
# Out:
#          Date  CountryID  Units  Country
# 0  03-01-2020          3     30  Pandama

# %% [markdown]
# LEFT_JOIN

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]
             }
left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'ID': [1,2, 3],
              'Country': ['USA', 'Canada', 'Panama']}
right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID Country
# 0   1     USA
# 1   2  Canada
# 2   3  Panama

# %%
left_join=left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID',how='left')

# %%
left_join
# Out:
#          Date  CountryID  Units  ID Country
# 0  01-01-2020          1     40   1     USA
# 1  02-01-2020          1     25   1     USA
# 2  03-01-2020          3     30   3  Panama
# 3  04-01-2020          2     35   2  Canada

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,4],
              'Units': [40, 25, 30, 35]}

left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          4     35

# %%
right_table = {'ID': [3],
              'Country': ['Pandama']}

right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama

# %%
right_join= left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID',how='right').drop('ID',axis=1)
right_join
# Out:
#          Date  CountryID  Units  ID  Country
# 0  03-01-2020          3     30   3  Pandama

# %% [markdown]
# FULL/OUTER JOIN

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020','05-03-2025' ],
              'CountryID': [1,1,3,2,5],
              'Units': [40, 25, 30, 35,45]}

left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35
# 4  05-03-2025          5     45

# %%
right_table = {'ID': [1,2,3,4],
              'Country': ['USA', 'Canada', 'Panama', 'Spain']}

right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID Country
# 0   1     USA
# 1   2  Canada
# 2   3  Panama
# 3   4   Spain

# %%
outer_join = left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID',how='outer').drop('ID',axis=1)
outer_join
# Out:
#          Date  CountryID  Units Country
# 0  01-01-2020        1.0   40.0     USA
# 1  02-01-2020        1.0   25.0     USA
# 2  04-01-2020        2.0   35.0  Canada
# 3  03-01-2020        3.0   30.0  Panama
# 4         NaN        NaN    NaN   Spain
# 5  05-03-2025        5.0   45.0     NaN

# %% [markdown]
# LEFT ANTI JOIN

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'ID': [3,4],
              'Country': ['Panama', 'Spain']}

right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID Country
# 0   3  Panama
# 1   4   Spain

# %%
left_join= left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID',how='left')
left_join
# Out:
#          Date  CountryID  Units   ID Country
# 0  01-01-2020          1     40  NaN     NaN
# 1  02-01-2020          1     25  NaN     NaN
# 2  03-01-2020          3     30  3.0  Panama
# 3  04-01-2020          2     35  NaN     NaN

# %%
left_join= left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID',how='left')
left_join[left_join['Country'].isna()][['Date','CountryID','Units']]
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 3  04-01-2020          2     35

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'ID': [3,4],
              'Country': ['Panama', 'Spain']}

right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID Country
# 0   3  Panama
# 1   4   Spain

# %%
left_anti_df=left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID',how='left',indicator=True)
left_anti_df
# Out:
#          Date  CountryID  Units   ID Country     _merge
# 0  01-01-2020          1     40  NaN     NaN  left_only
# 1  02-01-2020          1     25  NaN     NaN  left_only
# 2  03-01-2020          3     30  3.0  Panama       both
# 3  04-01-2020          2     35  NaN     NaN  left_only

# %%
left_anti_df.iloc[left_anti_df[]]#.drop(['ID','Country'],axis=1)
# Out:
#          Date  CountryID  Units     _merge
# 0  01-01-2020          1     40  left_only
# 1  02-01-2020          1     25  left_only
# 3  04-01-2020          2     35  left_only

# %%
left_anti_df = left_anti_df[['Date','CountryID','Units','_merge']]

# %%
left_anti_df
# Out:
#          Date  CountryID  Units     _merge
# 0  01-01-2020          1     40  left_only
# 1  02-01-2020          1     25  left_only
# 2  03-01-2020          3     30       both
# 3  04-01-2020          2     35  left_only

# %% [markdown]
# Right Anti join

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'ID': [3,4],
              'Country': ['Panama', 'Spain']}

right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID Country
# 0   3  Panama
# 1   4   Spain

# %%
right_join = left_table_df.merge(right_table_df,left_on='CountryID',right_on='ID',how='right',indicator=True)
right_join
# Out:
#          Date  CountryID  Units  ID Country      _merge
# 0  03-01-2020        3.0   30.0   3  Panama        both
# 1         NaN        NaN    NaN   4   Spain  right_only

# %% [markdown]
# CONCATENATION

# %%
left_anti_df
# Out:
#          Date  CountryID  Units   ID Country     _merge
# 0  01-01-2020          1     40  NaN     NaN  left_only
# 1  02-01-2020          1     25  NaN     NaN  left_only
# 2  03-01-2020          3     30  3.0  Panama       both
# 3  04-01-2020          2     35  NaN     NaN  left_only

# %%
right_join
# Out:
#          Date  CountryID  Units  ID Country      _merge
# 0  03-01-2020        3.0   30.0   3  Panama        both
# 1         NaN        NaN    NaN   4   Spain  right_only

# %%
pd.concat([left_anti_df,right_join],ignore_index=True)
# Out:
#          Date  CountryID  Units   ID Country      _merge
# 0  01-01-2020        1.0   40.0  NaN     NaN   left_only
# 1  02-01-2020        1.0   25.0  NaN     NaN   left_only
# 2  03-01-2020        3.0   30.0  3.0  Panama        both
# 3  04-01-2020        2.0   35.0  NaN     NaN   left_only
# 4  03-01-2020        3.0   30.0  3.0  Panama        both
# 5         NaN        NaN    NaN  4.0   Spain  right_only
