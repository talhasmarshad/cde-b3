# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
bricks = {"country": ['Brazil', 'Russia', 'India', 'China', 'South Africa'],
         "capital": ['Brazilia', 'Moscow', 'New Delhi', 'Beijing', 'Pretoria'],
         "area": [8.516, 17.100, 3.286, 9.597, 1.221],
         "population": [200.40, 143.50, 1252.00, 1357.00, 52.98]}

# %%
bricks_df = pd.DataFrame(bricks)
bricks_df
# Out:
#         country    capital    area  population
# 0        Brazil   Brazilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %%
bricks_df.index=['BR','RU','IN','CH','SU']

# %%
bricks_df
# Out:
#          country    capital    area  population
# BR        Brazil   Brazilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SU  South Africa   Pretoria   1.221       52.98

# %%
bricks_csv = pd.read_csv('./dataset/bricks.csv')

# %%
bricks_csv
# Out:
#   Unnamed: 0       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
##METHOD # 02
bricks_csv=pd.read_csv('./dataset/bricks.csv',index_col=0)

# %%
bricks_csv
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
country=bricks_csv['country']
country
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
type(country)
# Out:
# pandas.core.series.Series

# %%
country=bricks_csv[['country']]
country
# Out:
#          country
# BR        Brazil
# RU        Russia
# IN         India
# CH         China
# SA  South Africa

# %%
type(country)
# Out:
# pandas.core.frame.DataFrame

# %%
bricks_csv[['country','capital']]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
bricks_csv['country','capital']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('country', 'capital')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 bricks_csv['country','capital']
#
# ...

# %%
bricks_csv[0:2]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5

# %%
bricks_csv[1:4]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
bricks_csv[:4]
# Out:
#    country    capital    area  population
# BR  Brazil   Brasilia   8.516       200.4
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
bricks_csv[2:]
# Out:
#          country    capital   area  population
# IN         India  New Delhi  3.286     1252.00
# CH         China    Beijing  9.597     1357.00
# SA  South Africa   Pretoria  1.221       52.98

# %%
bricks_csv.loc['RU']
# Out:
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object

# %%
print(type(bricks_csv.loc['RU']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(bricks_csv.loc[['RU']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
bricks_csv.loc[['RU']]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
bricks_csv.loc[['RU','CH']]
# Out:
#    country  capital    area  population
# RU  Russia   Moscow  17.100       143.5
# CH   China  Beijing   9.597      1357.0

# %%
bricks_csv.loc[['RU','CH'],['country','capital']]
# Out:
#    country  capital
# RU  Russia   Moscow
# CH   China  Beijing

# %%
bricks_csv.loc['RU':'CH']
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
bricks_csv.loc[:,['country','capital']]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
bricks_csv
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
bricks_csv.iloc[[1]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
bricks_csv.iloc[[1,3,4]]
# Out:
#          country   capital    area  population
# RU        Russia    Moscow  17.100      143.50
# CH         China   Beijing   9.597     1357.00
# SA  South Africa  Pretoria   1.221       52.98

# %%
bricks_csv.iloc[[1,2,4],[0,3]]
# Out:
#          country  population
# RU        Russia      143.50
# IN         India     1252.00
# SA  South Africa       52.98

# %%
bricks_csv.iloc[:,[0,3]]
# Out:
#          country  population
# BR        Brazil      200.40
# RU        Russia      143.50
# IN         India     1252.00
# CH         China     1357.00
# SA  South Africa       52.98

# %%
bricks_csv.iloc[[1,3,4],1:3]
# Out:
#      capital    area
# RU    Moscow  17.100
# CH   Beijing   9.597
# SA  Pretoria   1.221

# %% [markdown]
# ASSIGNMENTS TASK

# %%
cars_csv = pd.read_csv('./dataset/cars.csv')

# %%
cars_csv
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JPN           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
cars_csv=pd.read_csv('./dataset/cars.csv',index_col=0)
cars_csv
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
country=cars_csv['country']
country
# Out:
# US     United States
# AUS        Australia
# JPN            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object

# %%
country = cars_csv[['country']]
country
# Out:
#            country
# US   United States
# AUS      Australia
# JPN          Japan
# IN           India
# RU          Russia
# MOR        Morocco
# EG           Egypt

# %%
cars_csv[0:2]
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False

# %%
cars_csv[1:4]
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# JPN           588      Japan         False
# IN             18      India         False

# %%
cars_csv.loc['AUS']
# Out:
# cars_per_cap          731
# country         Australia
# drives_right        False
# Name: AUS, dtype: object

# %%
cars_csv.loc[['AUS']]
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False

# %%
cars_csv.loc[['IN','AUS']]
# Out:
#      cars_per_cap    country  drives_right
# IN             18      India         False
# AUS           731  Australia         False

# %%
cars_csv.iloc[[1]]
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False

# %% [markdown]
# cars_csv.iloc[[1,3,4],[1]]

# %% [markdown]
# DATAFRAMES & AGGREGATING DATA

# %%
import numpy as np

# %%
titanic =pd.read_csv(r'C:\Users\Teacher\Documents\CDE-b3\exploratory-data-analysis-eda\Day 3 (DataFrames & Aggregating Data)\dataset\titanic.csv')

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# | **Column**      | **Description**                                                                                            |
# | --------------- | ---------------------------------------------------------------------------------------------------------- |
# | **PassengerId** | A unique identifier for each passenger.                                                                    |
# | **Survived**    | Survival status: `1` = Survived, `0` = Did not survive.                                                    |
# | **Pclass**      | Passenger class: `1` = First class, `2` = Second class, `3` = Third class. Reflects socio-economic status. |
# | **Name**        | Full name of the passenger, often includes title (e.g., Mr., Mrs., Miss, Master, Dr., etc.).               |
# | **Sex**         | Gender of the passenger: `male` or `female`.                                                               |
# | **Age**         | Age of the passenger in years. Some values may be missing.                                                 |
# | **SibSp**       | Number of siblings or spouses aboard the Titanic.                                                          |
# | **Parch**       | Number of parents or children aboard the Titanic.                                                          |
# | **Ticket**      | Ticket number (may be alphanumeric and not unique).                                                        |
# | **Fare**        | Fare paid for the ticket (in British pounds).                                                              |
# | **Cabin**       | Cabin number. May include multiple cabins or be missing.                                                   |
# | **Embarked**    | Port of Embarkation: `C` = Cherbourg, `Q` = Queenstown, `S` = Southampton.                                 |

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.sort_values(by='PassengerId')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_values(by='Age',ascending=False,na_position='last')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.sort_values(['Survived','Sex'])
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 838          839         1       3
# 839          840         1       1
# 857          858         1       1
# 869          870         1       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_values(['Survived','Sex'],ascending=[True,False])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 0                          Braund, Mr. Owen Harris    male  22.0      1
# 4                         Allen, Mr. William Henry    male  35.0      0
# 5                                 Moran, Mr. James    male   NaN      0
# 6                          McCarthy, Mr. Timothy J    male  54.0      0
# 7                   Palsson, Master. Gosta Leonard    male   2.0      3
# ..                                             ...     ...   ...    ...
# ...

# %%
titanic['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic[['Name','Survived']]
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [891 rows x 2 columns]

# %%
titanic['Age']>20
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic['Age']>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic['Sex']=='male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
sex_male=titanic['Sex']=='male'
not_survived = titanic['Survived']==0
titanic[sex_male & not_survived]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# TASK:
# 1) Gender should be female
# 2) Age is less than 20
# 3) or it survived

# %%
sex_male=titanic['Sex']=='male'
not_survived = titanic['Survived']==1
less_Age = titanic['Age']<20
titanic[sex_male & not_survived & less_Age]
# Out:
#      PassengerId  Survived  Pclass  \
# 78            79         1       2
# 125          126         1       3
# 165          166         1       3
# 183          184         1       2
# 193          194         1       2
# 204          205         1       3
# 220          221         1       3
# 226          227         1       2
# 261          262         1       3
# 283          284         1       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 407          408         1       2
# 445          446         1       1
# 489          490         1       3
# 549          550         1       2
# 550          551         1       1
# 751          752         1       3
# 755          756         1       2
# 788          789         1       3
# 802          803         1       1
# 803          804         1       3
# 827          828         1       2
# 831          832         1       2
# ...

# %%
titanic['Discount_Fare']=(titanic['Fare']/100)*25

# %%
titanic['Discount_Fare']
# Out:
# 0       1.812500
# 1      17.820825
# 2       1.981250
# 3      13.275000
# 4       2.012500
#          ...
# 886     3.250000
# 887     7.500000
# 888     5.862500
# 889     7.500000
# 890     1.937500
# Name: Discount_Fare, Length: 891, dtype: float64

# %%
Age_It_20= titanic[titanic.Age<20]
Desending_order = Age_It_20.sort_values('Age',ascending=False)
Desending_order [['Name','Age','Sex']]
# Out:
#                                 Name    Age     Sex
# 136     Newsom, Miss. Helen Monypeny  19.00  female
# 67          Crease, Mr. Ernest James  19.00    male
# 44     Devaney, Miss. Margaret Delia  19.00  female
# 27    Fortune, Mr. Charles Alexander  19.00    male
# 143              Burke, Mr. Jeremiah  19.00    male
# ..                               ...    ...     ...
# 831  Richards, Master. George Sibley   0.83    male
# 469    Baclini, Miss. Helene Barbara   0.75  female
# 644           Baclini, Miss. Eugenie   0.75  female
# 755        Hamalainen, Master. Viljo   0.67    male
# 803  Thomas, Master. Assad Alexander   0.42    male
#
# [164 rows x 3 columns]

# %%
titanic['Age'].mean()
# Out:
# np.float64(29.69911764705882)
